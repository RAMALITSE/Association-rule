# %%
# importing module
import pandas as pd
# dataset
dataset = pd.read_csv("sales.csv")
# printing the shape of the dataset
dataset.shape

# %%
dataset.head()

# %%
import numpy as np
# Gather All Items of Each Transactions into Numpy Array
transaction = []
for i in range(0, dataset.shape[0]):
    for j in range(0, dataset.shape[1]):
        transaction.append(dataset.values[i,j])
# converting to numpy array
transaction = np.array(transaction)
print(transaction)

# %%
transaction = []
for i in range(dataset.shape[0]):
    transaction.append([str(dataset.values[i,j]) for j in range(dataset.shape[1])])
# creating the numpy array of the transactions
transaction = np.array(transaction)
# importing the required module
from mlxtend.preprocessing import TransactionEncoder
# initializing the transactionEncoder
te = TransactionEncoder()
te_ary = te.fit(transaction).transform(transaction)
dataset = pd.DataFrame(te_ary, columns=te.columns_)
# dataset after encoded
dataset.head()

# %%
dataset.drop(['nan'], axis = 1, inplace = True )

# %%
dataset
# Out:
#        ADJ Rosy Sunglasses  Akron City Map  Akron Eyeglass Screwdriver  \
# 0                    False           False                       False
# 1                    False           False                       False
# 2                    False           False                       False
# 3                    False           False                       False
# 4                    False           False                       False
# ...                    ...             ...                         ...
# 20524                False           False                       False
# 20525                False           False                       False
# 20526                False           False                       False
# 20527                False           False                       False
# 20528                False           False                       False
#
#        American Beef Bologna  American Chicken Hot Dogs  American Cole Slaw  \
# ...

# %%
from mlxtend.frequent_patterns import apriori, association_rules, fpgrowth
freq_items = fpgrowth(dataset, min_support=0.000146, use_colnames=True, max_len=3, verbose=0)
rules = association_rules(freq_items, metric="confidence", min_threshold= 0.4 )
rules = rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
rules.sort_values(["confidence"],ascending=False).reset_index(drop= True).head(10)
# Out:
#                                          antecedents  \
# 0  (PigTail Low Fat Waffles, Fort West Low Fat BB...
# 1     (Ebony Squash, Big Time Frozen Chicken Thighs)
# 2  (Fort West Raspberry Fruit Roll, Tell Tale Gre...
# 3      (Hilltop 200 MG Ibuprofen, Fast Dried Apples)
# 4  (Red Spade Roasted Chicken, Hilltop 200 MG Ibu...
# 5  (Red Spade Roasted Chicken, Hilltop 200 MG Ibu...
# 6  (Red Spade Roasted Chicken, Red Wing 100 Watt ...
# 7  (Hilltop 200 MG Ibuprofen, Red Wing 100 Watt L...
# 8          (Sunset Paper Towels, Golden Pancake Mix)
# 9   (Golden Pancake Mix, Super Low Fat Apple Butter)
#
#                      consequents   support  confidence        lift
# 0              (Ebony Mushrooms)  0.000195         1.0  402.529412
# 1          (Even Better 1% Milk)  0.000146         1.0  353.948276
# 2    (Sphinx Pumpernickel Bread)  0.000146         1.0  336.540984
# 3    (Red Spade Roasted Chicken)  0.000195         1.0  418.959184
# ...

# %%
freq_items = fpgrowth(dataset, min_support=0.000146, use_colnames=True, max_len=3, verbose=0)
rules = association_rules(freq_items, metric="lift", min_threshold= 0.4 )
rules = rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
rules.sort_values(["lift"],ascending=False).reset_index(drop= True).head(10)
# Out:
#                                          antecedents  \
# 0  (Pearl White Zinfandel Wine, Denny Scented Tis...
# 1  (Even Better Mild Cheddar Cheese, Nationeel Gr...
# 2                             (High Top Fuji Apples)
# 3                             (High Top Fuji Apples)
# 4                                  (Good Light Beer)
# 5     (Moms Foot-Long Hot Dogs, High Top Tangerines)
# 6                    (Cormorant Copper Pot Scrubber)
# 7                            (Horatio Low Fat Chips)
# 8  (Steady Tartar Control Toothpaste, Big Time Fr...
# 9         (Hermanos Oranges, Landslide Apple Butter)
#
#                                          consequents   support  confidence  \
# 0                             (High Top Fuji Apples)  0.000146    1.000000
# 1                             (High Top Fuji Apples)  0.000146    1.000000
# 2  (Even Better Mild Cheddar Cheese, Nationeel Gr...  0.000146    0.085714
# 3  (Pearl White Zinfandel Wine, Denny Scented Tis...  0.000146    0.085714
# ...
